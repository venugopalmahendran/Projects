# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv('HR_comma_sep.csv')
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pd.crosstab(data.salary,data.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
salary_dum=pd.get_dummies(data.salary,dtype=int)

# %%
merage=pd.concat([data,salary_dum],axis='columns')
merage
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
finaldata=merage.drop('salary',axis='columns')
finaldata
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
model=LogisticRegression()

# %%
x=finaldata.drop('left',axis='columns',)
x
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# 1                       262                   6              0
# 2                       272                   4              0
# ...

# %%
y=finaldata.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 932                  0.42             0.52               2
# 1196                 0.37             0.55               2
# 8542                 0.52             0.76               4
# 2371                 0.78             0.98               5
# 10641                0.93             0.59               3
# ...                   ...              ...             ...
# 5771                 0.53             0.60               5
# 9257                 0.95             0.94               2
# 4484                 0.17             0.40               4
# 4288                 0.53             0.72               3
# 4742                 0.50             0.74               4
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 932                     151                   3              0
# 1196                    159                   3              0
# 8542                    106                   2              1
# ...

# %% [markdown]
# 1366	0.39	0.52	2	129	3	0	1	0	0	1	0

# %%
model.predict(x_test.head())
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_test.head()
# Out:
# 932      1
# 1196     1
# 8542     0
# 2371     0
# 10641    0
# Name: left, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.7846666666666666

# %%
import joblib
joblib.dump(model,filename='hr department model')
# Out:
# ['hr department model']

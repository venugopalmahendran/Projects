# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

data=pd.read_csv('insurance_data.csv')

# %%
plt.scatter(data.age,data.bought_insurance,color='g')
plt.show()

# %%
x=data.drop('bought_insurance',axis='columns')
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y=data.age
y
# Out:
# 0     22
# 1     25
# 2     47
# 3     52
# 4     46
# 5     56
# 6     55
# 7     60
# 8     62
# 9     61
# 10    18
# 11    28
# 12    27
# 13    29
# 14    49
# 15    55
# 16    25
# 17    58
# 18    19
# 19    18
# 20    21
# 21    26
# 22    40
# 23    45
# 24    50
# 25    54
# 26    23
# Name: age, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['age']],data.bought_insurance,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 10   18
# 13   29
# 4    46

# %%
model.predict(x_test)
# Out:
# array([0, 0, 1])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
import joblib

# %%
joblib.dump(model,filename='insurane apply model')
# Out:
# ['insurane apply model']
